# %%
import pandas as pd

# %%
df_can = pd.read_csv('Canada.csv')
df_can.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis=1, inplace=True)
print(df_can['Unnamed: 50'])
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1009   NaN
# 1010   NaN
# 1011   NaN
# 1012   NaN
# 1013   NaN
# Name: Unnamed: 50, Length: 1014, dtype: float64
